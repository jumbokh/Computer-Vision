# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/Computer-Vision/blob/main/notebooks/resize_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("lena.jpg")
rows,cols=img.shape[:2]
size=(int(cols*0.9),int(rows*0.5))
rst=cv2.resize(img,size)
print("img.shape=",img.shape)
print("rst.shape=",rst.shape)
# Out:
# img.shape= (512, 512, 3)
# rst.shape= (256, 460, 3)

# %%
cv2_imshow(img)
cv2_imshow(rst)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=460x256>
