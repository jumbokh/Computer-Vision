# %% [markdown]
# # 光學文字辨識(Optical Character Recognition, OCR)

# %% [markdown]
# ## 載入相關套件

# %%
# 載入相關套件
import cv2 
import pytesseract
import matplotlib.pyplot as plt

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/receipt.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## OCR 辨識

# %%
# 參數設定
custom_config = r'--psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Welcome to Mel's
# Check #: 0001 12/20/11
# Server: Jesh F 4:38 PM
# Table: 7/1 Guests: 2
# 2 Beef Burgr (€9.95/ea) 19,90
# SIDE: Fries
#
# 1 Bud Light 3.79
# 1 Bud 4.50
# Sub-total 28.19
# Sales Tax 2.50
# TOTAL 30.69
# Balance Due 30.69
#
# Thank you for your patronage! a

# %% [markdown]
# ## 只辨識數字

# %%
# 參數設定，只辨識數字
custom_config = r'--psm 6 outputbase digits'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# 0001 122011
# 4338-
# 71 2
# 29.95 19.90
# 1 3.79
# 1 4.50
# - 28.19
# 2.50
# 0 30.69
# 30.69

# %% [markdown]
# ## 只辨識有限字元

# %%
# 參數設定白名單，只辨識有限字元
custom_config = r'-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# elcometoels
# heck
# erverdeshf
# able uests
# eefurgrea
# efries
#
# udight
# ud
# ubtotal
# alesfax
# a
# alanceue
#
# hankyouforyourpatronage a

# %% [markdown]
# ## 設定黑名單，只辨識有限字元

# %%
# 參數設定黑名單，只辨識有限字元
custom_config = r'-c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# W  M]'
# C #: 0001 12/20/11
# S: J F 4:38 PM
# T: 7/1 G: 2
# 2 B B (€9.95/) 19,90
# SIDE: F
#
# 1 B L 3.79
# 1 B 4.50
# S-] 28.19
# S T 2.50
# TOTAL 30.69
# BI D 30.69
#
# T  é! ‘

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/chinese.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR % 8 AiR B47 HY OCR #88 > HP 2 8] #8 2005 ERA RAO AE AAG
# (Open Source) > LA C++ ES i RA? TR RABE RRR RARER
# Bete RPE > 44 https://github.com/UB-Mannheim tesseract/wiki
# F RURATIR exe HE > HE RESMT EP T > SER EAR > SER POE F bin F 8 BRIA
# inde SM Path PY BLA Python »f | Tesseract OCR > # 44 sb- RK pytesseract
# th? 48S do FP fe
#
# pip install pytesseract.

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/chinese_2.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR @ Bl HT?RER TAY OCR Heme HP ZS] IS 2005 AF BCR ATE UH (Open
# Source) > DA C++BAS2 TT RREY > CT FARA SIR Bs: REPRE EY
# fest > SUPPERS > SCA httos://eithub.com/UB-Mannheimvtesseractiwiki Paaeet
# hit exe 8 > EERSTE] » SSE RIS > HS SRASE IE P bin FE BRA Rey
# Path > 478224 Python "Al Tesseract OCR > FRED pytesseract BE FRSA
# Bt
#
# pip install pytesseract.
