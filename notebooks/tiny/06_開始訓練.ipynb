# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/Computer-Vision/blob/main/notebooks/tiny/06_%E9%96%8B%E5%A7%8B%E8%A8%93%E7%B7%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #本部份為執行darknet訓練
#
# 縮網址：https://twgo.io/figuo
#
# 步驟0：請建立副本存到自己的雲端硬碟
#
# 步驟1：連結到自己的雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 步驟2：檢查是否使用GPU

# %%
# !nvidia-smi
# Out:
# Sun Dec 24 14:13:16 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# 步驟3：進入darknet資料夾

# %%
# %cd drive/MyDrive/Colab\ Notebooks/darknet
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/darknet
# 3rdparty/               darknet.py                            libdarknet.so  src/
# backup/                 darknet_video.py                      LICENSE        uselib
# bread/                  data/                                 Makefile       vcpkg.json
# build/                  docker-compose.yml                    net_cam_v3.sh  vcpkg.json.opencv23
# build.ps1               Dockerfile.cpu                        net_cam_v4.sh  video_yolov3.sh
# cfg/                    Dockerfile.gpu                        obj/           video_yolov4.sh
# cmake/                  e47dc3c6d89a4cc2855a8f7438847a4c.jpg  package.xml    yolov4-tiny.weights
# CMakeLists.txt          image_yolov3.sh                       __pycache__/   yolov4.weights
# darknet                 image_yolov4.sh                       README.md      yolov7-tiny.weights
# DarknetConfig.cmake.in  include/                              results/       yolov7.weights
# ...

# %% [markdown]
# #執行YOLO-tiny訓練指令
#
# 1.第一次指令
#
# `!./darknet detector train bread/cfg/obj.data bread/cfg/yolov4-tiny.cfg bread/cfg/weights/yolov4-tiny.conv.29 -dont_show`
#
# 2.接續指令(如中斷，可以找到最後一次訓練結果接訓練)
#
# `!./darknet detector train bread/cfg/obj.data bread/cfg/yolov4-tiny.cfg bread/cfg/weights/yolov4-tiny_last.weights -dont_show`

# %%
# !chmod +x ./darknet
#第一次訓練
# !./darknet detector train bread/cfg/obj.data bread/cfg/yolov4-tiny.cfg bread/cfg/weights/yolov4-tiny.conv.29 -dont_show #第一次
#接續訓練時
#!./darknet detector train bread/cfg/obj.data bread/cfg/yolov4-tiny.cfg bread/cfg/weights/yolov4-tiny_last.weights -dont_show #中斷後
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.961223), count: 353, class_loss = 0.017592, iou_loss = 4.077358, total_loss = 4.094951
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.953904), count: 263, class_loss = 0.104297, iou_loss = 6.882842, total_loss = 6.987139
#  total_bbox = 7088193, rewritten_bbox = 0.000000 %
#
#  Tensor Cores are used.
# 11377/12000: loss=0.1 hours left=0.2
#  11377: 0.060991, 0.046926 avg loss, 0.000026 rate, 0.983095 seconds, 728128 images, 0.188594 hours left
# Loaded: 0.000098 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.961514), count: 391, class_loss = 0.017600, iou_loss = 4.581338, total_loss = 4.598938
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.958289), count: 298, class_loss = 0.041761, iou_loss = 13.318883, total_loss = 13.360644
# ...
